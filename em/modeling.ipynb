# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing all of the nrecesities

# %%
sales = pd.read_csv ('SalesForCourse_quizz_table.csv')

# %%
#Importing the table

# %%
sales.head()
# Out:
#    index      Date    Year     Month  Customer Age Customer Gender  \
# 0      0  02/19/16  2016.0  February          29.0               F
# 1      1  02/20/16  2016.0  February          29.0               F
# 2      2  02/27/16  2016.0  February          29.0               F
# 3      3  03/12/16  2016.0     March          29.0               F
# 4      4  03/12/16  2016.0     March          29.0               F
#
#          Country       State Product Category     Sub Category  Quantity  \
# 0  United States  Washington      Accessories  Tires and Tubes       1.0
# 1  United States  Washington         Clothing           Gloves       2.0
# 2  United States  Washington      Accessories  Tires and Tubes       3.0
# 3  United States  Washington      Accessories  Tires and Tubes       2.0
# 4  United States  Washington      Accessories  Tires and Tubes       3.0
#
#    Unit Cost  Unit Price   Cost  Revenue  Column1
# 0      80.00  109.000000   80.0    109.0      NaN
# ...

# %%
#Looking at the table and I see some nans

# %%
sales.Country.unique()
# Out:
# array(['United States', 'France', 'United Kingdom', 'Germany', nan],
#       dtype=object)

# %%
sales.Column1.unique()
# Out:
# array([        nan, 2370.      ,  398.      , ..., 1971.      ,
#        1568.      ,  687.344828])

# %%
sales['Customer Age'].unique()
# Out:
# array([29., 18., 19., 20., 22., 24., 40., 21., 23., 25., 30., 55., 53.,
#        52., 51., 50., 49., 48., 47., 46., 45., 41., 42., 65., 64., 32.,
#        33., 63., 34., 35., 43., 62., 37., 44., 60., 59., 58., 36., 61.,
#        57., 54., 38., 39., 27., 28., 17., 26., 67., 66., 71., 31., 56.,
#        87., 70., 69., 73., 68., 75., 86., 85., 77., 81., 84., 78., 72.,
#        80., 74., 76., 79., 82., nan])

# %%
sales['Customer Gender'].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
#Looking at the data

# %%
df = sales.drop(columns=['Column1', 'index'])

# %%
df.head()
# Out:
#        Date    Year     Month  Customer Age Customer Gender        Country  \
# 0  02/19/16  2016.0  February          29.0               F  United States
# 1  02/20/16  2016.0  February          29.0               F  United States
# 2  02/27/16  2016.0  February          29.0               F  United States
# 3  03/12/16  2016.0     March          29.0               F  United States
# 4  03/12/16  2016.0     March          29.0               F  United States
#
#         State Product Category     Sub Category  Quantity  Unit Cost  \
# 0  Washington      Accessories  Tires and Tubes       1.0      80.00
# 1  Washington         Clothing           Gloves       2.0      24.50
# 2  Washington      Accessories  Tires and Tubes       3.0       3.67
# 3  Washington      Accessories  Tires and Tubes       2.0      87.50
# 4  Washington      Accessories  Tires and Tubes       3.0      35.00
#
#    Unit Price   Cost  Revenue
# 0  109.000000   80.0    109.0
# 1   28.500000   49.0     57.0
# ...

# %%
#Cleaning up the Data

# %%
df1 = df[df.isna().any(axis=1)]

# %%
df1
# Out:
#       Date  Year Month  Customer Age Customer Gender Country State  \
# 34866  NaN   NaN   NaN           NaN             NaN     NaN   NaN
#
#       Product Category Sub Category  Quantity  Unit Cost  Unit Price  Cost  \
# 34866              NaN          NaN       NaN        NaN         NaN   NaN
#
#           Revenue
# 34866  641.532095

# %%
#Looking at what the null rows are, just one

# %%
df = df.dropna()

# %%
df
# Out:
#            Date    Year     Month  Customer Age Customer Gender  \
# 0      02/19/16  2016.0  February          29.0               F
# 1      02/20/16  2016.0  February          29.0               F
# 2      02/27/16  2016.0  February          29.0               F
# 3      03/12/16  2016.0     March          29.0               F
# 4      03/12/16  2016.0     March          29.0               F
# ...         ...     ...       ...           ...             ...
# 34861  03/22/15  2015.0     March          38.0               M
# 34862  02/07/16  2016.0  February          38.0               M
# 34863  03/13/15  2015.0     March          38.0               M
# 34864  04/05/15  2015.0     April          38.0               M
# 34865  08/30/15  2015.0    August          38.0               M
#
#              Country              State Product Category     Sub Category  \
# 0      United States         Washington      Accessories  Tires and Tubes
# ...

# %%
df.groupby('Customer Age')['Country'].apply(lambda x: x.count()>1).to_frame('Customer')
# Out:
#               Customer
# Customer Age
# 17.0              True
# 18.0              True
# 19.0              True
# 20.0              True
# 21.0              True
# ...                ...
# 82.0              True
# 84.0              True
# 85.0              True
# 86.0              True
# 87.0              True
#
# [70 rows x 1 columns]

# %%
#Trying to combine columns together

# %%
len(df.groupby('Customer Age')['Country'])
# Out:
# 70

# %%
(df.groupby('Customer Age')['State']).unique()
# Out:
# Customer Age
# 17.0    [Seine Saint Denis, England, Oregon, Nord, Val...
# 18.0    [California, Washington, Oregon, Essonne, Baye...
# 19.0    [Oregon, Washington, California, Seine (Paris)...
# 20.0    [Washington, California, Loiret, Essonne, Haut...
# 21.0    [Washington, Oregon, California, Saarland, Hau...
#                               ...
# 82.0                                      [Seine (Paris)]
# 84.0                [England, Yveline, Seine Saint Denis]
# 85.0                       [England, Nordrhein-Westfalen]
# 86.0                                  [Saarland, Yveline]
# 87.0                                           [Saarland]
# Name: State, Length: 70, dtype: object

# %%
(df.groupby('Customer Age')['Country']).unique()
# Out:
# Customer Age
# 17.0    [France, United Kingdom, United States, Germany]
# 18.0    [United States, France, Germany, United Kingdom]
# 19.0    [United States, France, Germany, United Kingdom]
# 20.0    [United States, France, Germany, United Kingdom]
# 21.0    [United States, Germany, France, United Kingdom]
#                               ...
# 82.0                                            [France]
# 84.0                            [United Kingdom, France]
# 85.0                           [United Kingdom, Germany]
# 86.0                                   [Germany, France]
# 87.0                                           [Germany]
# Name: Country, Length: 70, dtype: object

# %%
(df.groupby('Unit Cost')['Unit Price']).unique()
# Out:
# Unit Cost
# 0.67                           [0.666667, 1.0, 1.333333]
# 1.00                                          [1.5, 1.0]
# 1.33                           [1.333333, 2.0, 1.666667]
# 1.67       [2.0, 2.666667, 2.333333, 1.666667, 1.333333]
# 2.00                                     [2.0, 3.0, 2.5]
#                                ...
# 2640.00                                         [4008.0]
# 2760.00                                         [3428.0]
# 3000.00                                         [3787.0]
# 3120.00                                 [3887.0, 4113.0]
# 3240.00                                         [5082.0]
# Name: Unit Price, Length: 882, dtype: object

# %%
(df.groupby('Cost')['Quantity']).unique()
# Out:
# Cost
# 2.0       [3.0, 1.0, 2.0]
# 4.0       [2.0, 3.0, 1.0]
# 5.0       [2.0, 3.0, 1.0]
# 7.0       [1.0, 2.0, 3.0]
# 8.0       [2.0, 1.0, 3.0]
#                ...
# 2760.0         [2.0, 1.0]
# 3000.0              [1.0]
# 3120.0         [1.0, 3.0]
# 3240.0         [1.0, 3.0]
# 3600.0         [2.0, 3.0]
# Name: Quantity, Length: 417, dtype: object

# %%
#After looking at group pairings, I decided to combine them all

# %%
groups = df.groupby(['Customer Age', 'Customer Gender','Country','State'])['Cost'].mean()

# %%
groups.head(20)
# Out:
# Customer Age  Customer Gender  Country         State
# 17.0          F                France          Essonne                400.500000
#                                                Hauts de Seine         295.250000
#                                                Loiret                  44.000000
#                                                Nord                   460.000000
#                                                Seine (Paris)          181.400000
#                                                Seine Saint Denis      335.666667
#                                                Yveline                 95.000000
#                                Germany         Bayern                 317.500000
#                                                Brandenburg            325.000000
#                                                Hamburg                400.800000
#                                                Hessen                 235.000000
# ...

# %%
groups.plot()
plt.show()

# %%
#Started to create visuals, kinda messy

# %%
df.plot.scatter(x="Cost", y="Customer Age", alpha=0.5,figsize=(16, 12), subplots=True)
plt.show()

# %%
df.plot.scatter(x="Unit Cost", y="Customer Age", alpha=0.5,figsize=(16, 12), subplots=True)
plt.show()

# %%
#making some graphs based on item cost and age

# %%
df.plot.scatter(x="Country", y="State", alpha=0.1,figsize=(4, 8), subplots=True)
plt.show()

# %%
#Checking to see which places have the most customers

# %%
sns.displot(data=df, x="Country", hue="State", multiple="stack")
plt.show()

# %%
# A slightly better graph than the previous one, but it is a little scuffed

# %%
sns.displot(data=df, x="Customer Age", hue="Customer Gender", multiple="stack", kind="kde")
plt.show()

# %%
#Comparing the genders of the customers, with a majority being female.

# %%
sns.pairplot(data=df, hue="Country")
plt.show()

# %%
# Seeing which graph can prove to be interesting

# %%
sns.relplot(data=df, x="Unit Price", y="Unit Cost", hue="Country")
plt.show()

# %%
#This was the most interesting, showing who are the highest spenders

# %%
sns.displot(data=df, x="Country", hue="Customer Gender", multiple="stack")
plt.show()

# %%
#This graph shows the general demographics
