# %%
import pandas as pd
import re
import os
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
import unicodedata

import warnings
warnings.filterwarnings('ignore')

# %%
# import kaggle

# %%
# api.dataset_download_files('lokeshparab/amazon-products-dataset', path="Cycling.csv")
# !kaggle datasets download -d lokeshparab/amazon-products-dataset -f cycling.csv

# %%
# from kaggle.api.kaggle_api_extended import KaggleApi
# api = KaggleApi()
# api.authenticate()

# %%
# api.datasets_download_file('lokeshparab', 'amazon-products-dataset/', 
#                            file_name='cycling.csv')

# %%
def acquire_amazon():
    '''
    This will acqurie the Cycling category Amazon product data from either local cached
    file or from kaggle.com
    
    returns: uncleaned dataframe
    '''
    # set filename
    filename = 'amazon_cycling.csv'
    # check if local cached version of the file exists
    if os.path.exists(filename):
        # display status message
        print(f'Opening local {filename} file')
        # open local file data
        df = pd.read_csv(filename)
    # if there is no local file
    else:
        # display status message
        print(f'Local file {filename} not found')
        print('downloading data')
        # set url path to the dataset
        path = '''https://storage.googleapis.com/kagglesdsdata/datasets/3020336/5239462/Cycling.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230601%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230601T202559Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...'''
        # read the data from the url path
        df = pd.read_csv(path)
        # cache the data to local csv file
        df.to_csv(filename, index=False)
    # return the dataframe
    return df

# %%
def basic_clean(original_string):
    '''
    This will take in a string, make it all lowercase, normalize the characters to ascii
    and remove characters that are not letters, numbers or spaces
    '''
    original_string = original_string.replace('|',' ').replace('/', ' ')
    # normalize the characters to ascii standart
    normalized = unicodedata.normalize('NFKD', original_string).\
        encode('ascii', 'ignore').decode('utf-8')
    # lowercase all the words in the data
    lowered = normalized.lower()
    # remove things that arent letters, numbers and spaces
    basic_cleaned = re.sub(r'[^a-zA-Z0-9\s]', '', lowered)
    #return the cleaned string
    return basic_cleaned

# %%
def tokenize(basic_cleaned):
    '''
    This will break up words into smaller, discrete (tokenized) units
    '''
    # grab our tokenizer from nltk
    tokenizer = nltk.tokenize.ToktokTokenizer()
    # tokenize the data
    tokenized = tokenizer.tokenize(basic_cleaned, return_str=True)
    # return the tokenized data
    return tokenized

# %%
def lemmatize(tokenized):
    '''
    This will cut a string of words down into their root words (Lemmatizing)
    '''
    # create lemmatizer object
    lemmatizer = nltk.stem.WordNetLemmatizer()
    # lemmatize every word in the string
    lemmatized = ' '.join([lemmatizer.lemmatize(word) for word in tokenized.split()])
    # return the lemmatized string
    return lemmatized

# %%
def remove_stopwords(string, extra_words=None, exclude_words=None):
    '''
    This will remove words that hold little meaning to a machine learning system
    such as: 'the' 'am', 'is', 'are',
    '''
    # get a list of the stopwords
    stopwords = nltk.corpus.stopwords.words('english')
    # add extra words to the stopwords list
    if extra_words:
        [stopwords.append(word) for word in extra_words]
    # remove the exclude words from the stopwords list if word is in the stopwords list
    if exclude_words:
        [stopwords.remove(word) for word in exclude_words 
                     if (word in stopwords)]
    # get the list of words that are not in the stopwords
    stops_removed = ' '.join([word for word in string.split() 
                              if word not in stopwords])
    # return the words not in the stopwords list
    return stops_removed

# %%
def clean_names(df, extra_words=None, exclude_words=None):
    '''
    This will clean/normalize, tokenize and lemmatize the product names from amazon in 
    preparation of using nlp on it.
    '''
    # create an empty list to store the names
    names = []
    # cycle through all the product names
    for name in df.name:
        # clean the product name
        basic_cleaned = basic_clean(name)
        # tokenize the words in the name
        tokenized = tokenize(basic_cleaned)
        # remove the stopwords from the product name
        cleaned = remove_stopwords(tokenized, 
                                   extra_words=extra_words, 
                                   exclude_words=exclude_words)
        # get the lemmatized words from the product name
        lemmatized = lemmatize(cleaned)
        # add the lemmatized name to the list of names
        names.append(lemmatized)
        
    # add the lemmatized version of the name to the original df
    df['name_preped'] = names
    # return the df
    return df

# %%
def prepare_amazon(df, extra_words=None, exclude_words=None):
    '''
    This will clean/normalize/tokenize/lemmatize the name column of the amazon products,
    it will also replace some nonsense values in the ratings columns with 0s and 
    remove Indian rupee symbol. It will then convert the correct dtypes,
    and convert the prices from Indian rupee into US dollars. Then it will
    create new columns for the discount_amount and rating_prod
    '''
    # clean/tokenize/lemmatize the product names so we can use regex on them later
    cleaned = clean_names(df, extra_words=None, exclude_words=None)
    
    # change nonsense rating values into 0s and convert dtypes
    cleaned.ratings = cleaned.ratings.str.strip().\
        str.replace(' ', '', regex=False).\
        str.replace(',','', regex=False).\
        str.replace('Get', '0', regex=False).\
        fillna('0').astype(float)
    cleaned.no_of_ratings = cleaned.no_of_ratings.str.strip().\
        str.replace(' ', '', regex=False).\
        str.replace(',','', regex=False).\
        str.replace('FREEDeliverybyAmazon', '0', regex=False).\
        str.replace('Only1leftinstock.', '0', regex=False).\
        str.replace('Only2leftinstock.', '0', regex=False).\
        fillna('0').astype(int)
    
    # remove rows without actual prices since they are probably not available
    cleaned = cleaned[cleaned.actual_price.isna() == False]
    # clean the prices and convert to float dtype
    cleaned.discount_price = cleaned.discount_price.str.strip().\
        str.replace('₹','', regex=False).\
        str.replace(',','', regex=False).astype(float)
    cleaned.actual_price = cleaned.actual_price.str.strip().\
        str.replace('₹','', regex=False).\
        str.replace(',','', regex=False).astype(float)
    # if there is no discount_price we will assume the actual_price
    cleaned.discount_price = cleaned.discount_price.fillna(cleaned.actual_price)
    
    # convert the prices from Indian rupees into US dollars (1 rupee = 0.012 dollars)
    cleaned.actual_price = round(cleaned.actual_price * 0.012, 2)
    cleaned.discount_price = round(cleaned.discount_price * 0.012, 2)
    
    # lets create a new column with the amount of discount
    cleaned['discount_amount'] = cleaned.actual_price - cleaned.discount_price
    # create a new column that is the product of avg ratings and no_of_ratings
    # so that we can get a rankings of all the products
    cleaned['prod_rating'] = cleaned.ratings * cleaned.no_of_ratings
    
    # rename columns to avoid confustion
    cleaned = cleaned.rename(columns={'main_category':'amazon_main_cat',
                                      'sub_category': 'amazon_sub_cat'})
    # reset the index after dropping null rows
    cleaned = cleaned.reset_index().drop(columns='index')
    
    # return the cleaned dataframe
    return cleaned

# %%
def wrangle_products():
    '''
    This will perform the acquisitioin and preparing of the amazon product info
    '''
    # acquire amazon product data
    df = acquire_amazon()
    # prepare the data
    cleaned = prepare_amazon(df)
    # return the prepared data
    return cleaned

# %%
def get_cat_list(cat_list, extra_words=None, exclude_words=None):
    cats = []
    # cycle through all the product cats
    for cat in cat_list:
        # clean the product cat
        basic_cleaned = basic_clean(cat)
        # tokenize the words in the cat
        tokenized = tokenize(basic_cleaned)
        # remove the stopwords from the product cat
        cleaned = remove_stopwords(tokenized,
                                   extra_words=extra_words,
                                   exclude_words=exclude_words)
        # get the lemmatized words from the product cat
        lemmatized = lemmatize(cleaned)
        # add the lemmatized cat to the list of cats
        cats.append(lemmatized)
    # return a list of categories that are cleaned and lemmatized 
    # whiich we can match to our product names
    return cats

# %%
df = acquire_amazon()
# Out:
# Opening local amazon_cycling.csv file

# %%
cleaned = clean_names(df)
cleaned.head()
# Out:
#                                                 name     main_category  \
# 0  QUXIS Portable High Pressure Foot Air Pump Hea...  sports & fitness
# 1  Boldfit Gym Shaker for Protein Shake Leakproof...  sports & fitness
# 2  Techista 2-in-1 Rechargeable - Cycle Light (3 ...  sports & fitness
# 3  Nivia Plain Encounter Stockings (L, Black) - P...  sports & fitness
# 4  Eazo Steel Multipurpose Air Pump with needle (...  sports & fitness
#
#   sub_category                                              image  \
# 0      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/QUXIS-Portable-Activated...     4.0         7,635
# 1  https://www.amazon.in/Boldfit-Typhoon-Shaker-L...     4.1         8,052
# 2  https://www.amazon.in/Techista-2-1-Rechargeabl...     4.1         2,214
# 3  https://www.amazon.in/Nivia-728LBW-Encounter-B...     4.1         2,974
# 4  https://www.amazon.in/EAZO-Steel-Multipurpose-...     4.1         3,678
#
#   discount_price actual_price  \
# 0           ₹499       ₹1,299
# 1            NaN         ₹229
# 2           ₹339         ₹999
# 3           ₹145         ₹149
# 4           ₹369         ₹450
#
#                                          name_preped
# 0  quxis portable high pressure foot air pump hea...
# 1  boldfit gym shaker protein shake leakproof sha...
# 2  techista 2in1 rechargeable cycle light 3 mode ...
# 3  nivia plain encounter stocking l black polyest...
# 4  eazo steel multipurpose air pump needle use ca...

# %%
cleaned.name_preped.replace('|',' ')[13]
# Out:
# 'leader scout mtb 26t mountain bicycle bike without gear single speed men sea green ideal 10 year frame siz'

# %%
cleaned.name[13]
# Out:
# 'Leader Scout MTB 26T Mountain Bicycle/Bike Without Gear Single Speed for Men - Sea Green, Ideal for 10 + Years, Frame Siz...'

# %%
df = wrangle_products()
# Out:
# Opening local amazon_cycling.csv file

# %%
df.shape
# Out:
# (1117, 12)

# %%
df.head()
# Out:
#                                                 name   amazon_main_cat  \
# 0  QUXIS Portable High Pressure Foot Air Pump Hea...  sports & fitness
# 1  Boldfit Gym Shaker for Protein Shake Leakproof...  sports & fitness
# 2  Techista 2-in-1 Rechargeable - Cycle Light (3 ...  sports & fitness
# 3  Nivia Plain Encounter Stockings (L, Black) - P...  sports & fitness
# 4  Eazo Steel Multipurpose Air Pump with needle (...  sports & fitness
#
#   amazon_sub_cat                                              image  \
# 0        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/QUXIS-Portable-Activated...      4.0           7635
# 1  https://www.amazon.in/Boldfit-Typhoon-Shaker-L...      4.1           8052
# 2  https://www.amazon.in/Techista-2-1-Rechargeabl...      4.1           2214
# 3  https://www.amazon.in/Nivia-728LBW-Encounter-B...      4.1           2974
# 4  https://www.amazon.in/EAZO-Steel-Multipurpose-...      4.1           3678
#
#    discount_price  actual_price  \
# 0            5.99         15.59
# 1            2.75          2.75
# 2            4.07         11.99
# 3            1.74          1.79
# 4            4.43          5.40
#
#                                          name_preped  discount_amount  \
# 0  quxis portable high pressure foot air pump hea...             9.60
# 1  boldfit gym shaker protein shake leakproof sha...             0.00
# 2  techista 2in1 rechargeable cycle light 3 mode ...             7.92
# 3  nivia plain encounter stocking l black polyest...             0.05
# 4  eazo steel multipurpose air pump needle use ca...             0.97
#
#    prod_rating
# 0      30540.0
# 1      33013.2
# 2       9077.4
# 3      12193.4
# 4      15079.8

# %%
cleaned.shape
# Out:
# (1152, 10)

# %%
cleaned.isna().sum()
# Out:
# name                0
# main_category       0
# sub_category        0
# image               0
# link                0
# ratings           273
# no_of_ratings     273
# discount_price    178
# actual_price       35
# name_preped         0
# dtype: int64

# %% [markdown]
# ### If there are no ratings, then ratings and no_of_ratings will both be nan. So lets fill those nulls with 0.
# ### Ift there is no actual_price it could either be an data entry error or a product that is no longer available. If there is no actual_price, there will also be nulls in discount_price and discount_amount. I think we should look at these as not available, and we will not want to recommend products that are not available. So lets drop the nulls without prices.

# %%
cleaned = cleaned[cleaned.actual_price.isna() == False]

# %%
cleaned.head(2)
# Out:
#                                                 name     main_category  \
# 0  QUXIS Portable High Pressure Foot Air Pump Hea...  sports & fitness
# 1  Boldfit Gym Shaker for Protein Shake Leakproof...  sports & fitness
#
#   sub_category                                              image  \
# 0      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/QUXIS-Portable-Activated...     4.0         7,635
# 1  https://www.amazon.in/Boldfit-Typhoon-Shaker-L...     4.1         8,052
#
#   discount_price actual_price  \
# 0           ₹499       ₹1,299
# 1            NaN         ₹229
#
#                                          name_preped
# 0  quxis portable high pressure foot air pump hea...
# 1  boldfit gym shaker protein shake leakproof sha...

# %%
cleaned.shape
# Out:
# (1117, 10)

# %%
cleaned.discount_price = cleaned.discount_price.\
    str.replace('₹','', regex=False).\
    str.replace(',','', regex=False).astype(float)

# %%
cleaned.actual_price = cleaned.actual_price.\
    str.replace('₹','', regex=False).\
    str.replace(',','', regex=False).astype(float)

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1117 entries, 0 to 1151
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1117 non-null   object
#  1   main_category   1117 non-null   object
#  2   sub_category    1117 non-null   object
#  3   image           1117 non-null   object
#  4   link            1117 non-null   object
#  5   ratings         856 non-null    object
#  6   no_of_ratings   856 non-null    object
#  7   discount_price  974 non-null    float64
#  8   actual_price    1117 non-null   float64
#  9   name_preped     1117 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 96.0+ KB

# %%
cleaned.discount_price = cleaned.discount_price.fillna(cleaned.actual_price)

# %%
cleaned['discount_amount'] = cleaned.actual_price - cleaned.discount_price

# %%
cleaned.discount_price.value_counts()
# Out:
# 499.00      43
# 299.00      35
# 399.00      34
# 599.00      29
# 199.00      28
#             ..
# 560.82       1
# 4829.00      1
# 254.00       1
# 7605.00      1
# 14250.00     1
# Name: discount_price, Length: 519, dtype: int64

# %%
cleaned.head(3)
# Out:
#                                                 name     main_category  \
# 0  QUXIS Portable High Pressure Foot Air Pump Hea...  sports & fitness
# 1  Boldfit Gym Shaker for Protein Shake Leakproof...  sports & fitness
# 2  Techista 2-in-1 Rechargeable - Cycle Light (3 ...  sports & fitness
#
#   sub_category                                              image  \
# 0      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/QUXIS-Portable-Activated...     4.0         7,635
# 1  https://www.amazon.in/Boldfit-Typhoon-Shaker-L...     4.1         8,052
# 2  https://www.amazon.in/Techista-2-1-Rechargeabl...     4.1         2,214
#
#    discount_price  actual_price  \
# 0           499.0        1299.0
# 1           229.0         229.0
# 2           339.0         999.0
#
#                                          name_preped  discount_amount
# 0  quxis portable high pressure foot air pump hea...            800.0
# 1  boldfit gym shaker protein shake leakproof sha...              0.0
# 2  techista 2in1 rechargeable cycle light 3 mode ...            660.0

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1117 entries, 0 to 1151
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1117 non-null   object
#  1   main_category    1117 non-null   object
#  2   sub_category     1117 non-null   object
#  3   image            1117 non-null   object
#  4   link             1117 non-null   object
#  5   ratings          856 non-null    object
#  6   no_of_ratings    856 non-null    object
#  7   discount_price   1117 non-null   float64
#  8   actual_price     1117 non-null   float64
#  9   name_preped      1117 non-null   object
#  10  discount_amount  1117 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 104.7+ KB

# %%
cleaned.no_of_ratings = cleaned.no_of_ratings.str.strip().str.replace(',','',).\
    str.replace(' ','')

# %%
cleaned.head(2)
# Out:
#                                                 name     main_category  \
# 0  QUXIS Portable High Pressure Foot Air Pump Hea...  sports & fitness
# 1  Boldfit Gym Shaker for Protein Shake Leakproof...  sports & fitness
#
#   sub_category                                              image  \
# 0      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/QUXIS-Portable-Activated...     4.0          7635
# 1  https://www.amazon.in/Boldfit-Typhoon-Shaker-L...     4.1          8052
#
#    discount_price  actual_price  \
# 0           499.0        1299.0
# 1           229.0         229.0
#
#                                          name_preped  discount_amount
# 0  quxis portable high pressure foot air pump hea...            800.0
# 1  boldfit gym shaker protein shake leakproof sha...              0.0

# %%
# cleaned.no_of_ratings = cleaned.no_of_ratings.astype(float)

# %%
cleaned.no_of_ratings.unique()
# Out:
# array(['7635', '8052', '2214', '2974', '3678', '1444', '8334', '66',
#        '566', '6580', '5117', '1601', '2759', '3457', '46', '632',
#        '12842', '6596', '2507', '708', '1022', '1062', '768', '487',
#        '268', '81', '447', '169', '424', '416', '485', '1', '23', '1145',
#        '300', '2589', '252', '1270', '78', '144', '13', '65', '287',
#        '4207', '203', '15', '121', '247', '870', '10244', '128', '1623',
#        '316', '6083', '536', '26', '25', '2839', '180', '48', '29',
#        '18123', '135', '1639', '1873', '157', '98', '240', '291', '1848',
#        '2757', '1373', '16', '3', '241', '202', '75', '453', '2472', '24',
#        '36', '951', '2', '4', '156', '125', '8', '51', '6', '383', '74',
#        nan, '20', '50', '5', '119', '278', '18', '10', '14', '184', '133',
#        '430', '159', '33', '9', '31', '12', '30', '64', '1111', '68',
#        '104', '17', '267', '131', '54', '53', '39', '11', '255', '55',
#        '130', '34', '59', '41', '40', '346', '149',
#        'FREEDeliverybyAmazon', '187', '122', '49', '7', '179', '22',
#        '391', '58', '62', 'Only1leftinstock.', '60', '393', '82', '88',
#        '113', '21', '232', '838', '56', '32', '89', '523', '272', '27',
#        '19', '109', '139', '154', '111', '844', '69', '52', '19181',
#        '243', '635', '43', '177', '13444', '73', '462', '168', '42',
#        '298', '38', '85', '35', '186', '72', '95', '175', '4629', '335',
#        '2069', '505', '28', '733', '196', '87', '421', '182', '37', '297',
#        'Only2leftinstock.', '1742', '6745', '138', '4200', '1906', '57',
#        '79', '91', '63', '146', '77', '148', '71', '76', '155', '192',
#        '47', '90', '1815', '103', '229', '16596', '67', '161', '2956'],
#       dtype=object)

# %% [markdown]
# ### FFS why is there 'FREEDeliverybyAmazon' in the no_of_ratings column. Let's check out these nonsense rows.

# %%
cleaned[cleaned.no_of_ratings == 'FREEDeliverybyAmazon']
# Out:
#                                                    name     main_category  \
# 214      BODYCARE Unisex Kids Thermal Bottoms Pack Of 1  sports & fitness
# 245                  Puma Footie Unisex Socks Pack of 3  sports & fitness
# 261   Charged Active-001 Camo Jacquard Round Neck Sp...  sports & fitness
# 272   Van Heusen&comma;VH Woman Women's Relaxed Fit ...  sports & fitness
# 412   Adidas Unisex Mufc H So Socks (H13893_L, White...  sports & fitness
# 466   Charged Active-001 Camo Jacquard Round Neck Sp...  sports & fitness
# 482   Charged Active-001 Camo Jacquard Round Neck Sp...  sports & fitness
# 483   Charged Active-001 Camo Jacquard Polyester Rou...  sports & fitness
# 489   Charged Active-001 Camo Jacquard Round Neck Sp...  sports & fitness
# 510                    ONN Men's Premium Thermal Bottom  sports & fitness
# 679   Charged Brisk-002 Melange Round Neck Sports T-...  sports & fitness
#
# 679   https://www.amazon.in/Charged-Brisk-002-Melang...     Get
# 680   https://www.amazon.in/ASICS-Womens-Regular-T-S...     Get
# 681   https://www.amazon.in/Dixcy-Scott-Melange-Prem...     Get
# 725   https://www.amazon.in/Nivia-2364-1-Nitro-1-Pol...     Get
# 741   https://www.amazon.in/Lacoste-Branded-Stretch-...     Get
# 869   https://www.amazon.in/Charged-Energy-004-Inter...     Get
# 870   https://www.amazon.in/Charged-Brisk-002-Melang...     Get
# 871   https://www.amazon.in/Brisk-002-Polyester-Inte...     Get
# 875   https://www.amazon.in/Dixcy-Scott-Charcoal-Mel...     Get
# 933   https://www.amazon.in/SJCAM-Action-Resistant-M...     Get
# 1009  https://www.amazon.in/GS-1771JR-Black-Heather-...     Get
# 1089  https://www.amazon.in/Play-005-Interlock-Geoma...     Get
# 1090  https://www.amazon.in/Endure-003-Chameleon-Int...     Get
# 1091  https://www.amazon.in/Endure-003-Chameleon-Int...     Get
# 1116  https://www.amazon.in/Dixcy-Scott-Charcoal-Mel...     Get
# 1144  https://www.amazon.in/ONN-Sleeves-Premium-Ther...     Get
#
#              no_of_ratings  discount_price  actual_price  \
# 214   FREEDeliverybyAmazon           625.0         625.0
# 245   FREEDeliverybyAmazon           599.0         599.0
# 261   FREEDeliverybyAmazon          1196.0        1348.0
# 272   FREEDeliverybyAmazon          1059.0        1059.0
# 412   FREEDeliverybyAmazon           919.0        1499.0
# 466   FREEDeliverybyAmazon          1198.0        1198.0
# 482   FREEDeliverybyAmazon          1248.0        1248.0
# 483   FREEDeliverybyAmazon          1198.0        1198.0
# 489   FREEDeliverybyAmazon          1196.0        1348.0
# 510   FREEDeliverybyAmazon           690.0         690.0
# 679   FREEDeliverybyAmazon           716.0        1098.0
# 680   FREEDeliverybyAmazon           849.0        1699.0
# 681   FREEDeliverybyAmazon           647.0         647.0
# 725   FREEDeliverybyAmazon           629.0         629.0
# 741   FREEDeliverybyAmazon          1750.0        1750.0
# 869   FREEDeliverybyAmazon           987.0        1048.0
# 870   FREEDeliverybyAmazon          1017.0        1148.0
# 871   FREEDeliverybyAmazon          1098.0        1098.0
# 875   FREEDeliverybyAmazon           628.0         628.0
# 933   FREEDeliverybyAmazon          3999.0       11000.0
# 1009  FREEDeliverybyAmazon          1714.0        1950.0
# 1089  FREEDeliverybyAmazon           683.0         998.0
# 1090  FREEDeliverybyAmazon          1148.0        1148.0
# 1091  FREEDeliverybyAmazon          1011.0        1148.0
# 1116  FREEDeliverybyAmazon           609.0         609.0
# 1144  FREEDeliverybyAmazon           620.0         620.0
#
#                                             name_preped  discount_amount
# 214           bodycare unisex kid thermal bottom pack 1              0.0
# 245                      puma footie unisex sock pack 3              0.0
# 261   charged active001 camo jacquard round neck spo...            152.0
# 272    van heusencommavh woman woman relaxed fit tshirt              0.0
# 412           adidas unisex mufc h sock h13893l white l            580.0
# 466   charged active001 camo jacquard round neck spo...              0.0
# 482   charged active001 camo jacquard round neck spo...              0.0
# 483   charged active001 camo jacquard polyester roun...              0.0
# 489   charged active001 camo jacquard round neck spo...            152.0
# 510                      onn men premium thermal bottom              0.0
# 679   charged brisk002 melange round neck sport tshi...            382.0
# 680                      asics woman regular fit tshirt            850.0
# 681   dixcy scott grey melange men premium lower tro...              0.0
# 725   nivia 23641 nitro1 polyester training tee adul...              0.0
# 741   lacoste men sport branded stretch cotton lowcu...              0.0
# 869   charged energy004 interlock knit hexagon embos...             61.0
# 870   charged brisk002 melange round neck sport tshi...            131.0
# 871   charged brisk002 melange round neck sport tshi...              0.0
# 875   dixcy scott charcoal melange men premium lower...              0.0
# 933   renewed sjcam action camera c100 2k 30fps 30m ...           7001.0
# 1009  yonex girl junior sport legging madel 1771 bad...            236.0
# 1089  charged play005 interlock knit geomatric embos...            315.0
# 1090  charged endure003 chameleon spandex knit round...              0.0
# 1091  charged endure003 chameleon spandex knit round...            137.0
# 1116  dixcy scott charcoal melange v neck full sleev...              0.0
# 1144  onn men round neck half sleeve premium thermal...              0.0

# %%
cleaned[cleaned.no_of_ratings == 'Only1leftinstock.']
# Out:
#                                                    name     main_category  \
# 246   IndiaLot® Bicycle Tyre 20x 2.125/1.95/1.90/1.7...  sports & fitness
# 424   DIKUDI CREATION Doraemon Rider Infant to Toddl...  sports & fitness
# 1017  Dhara Kid Bicycle 3-5 Years Size 14T Unisex Cy...  sports & fitness
# 1027  Layfuz 32T/34T/36T/38T Bike Chainring 104mm B ...  sports & fitness
#
#      sub_category                                              image  \
# 246       Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 424       Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1017      Cycling  https://m.media-amazon.com/images/I/51xytb8F7S...
# 1027      Cycling  https://m.media-amazon.com/images/I/71Om35SiQ0...
#
#                                                    link ratings  \
# 246   https://www.amazon.in/IndiaLot%C2%AE-Bicycle-T...     Get
# 424   https://www.amazon.in/DIKUDI-CREATION-Doraemon...     Get
# 1017  https://www.amazon.in/Dhara-Bicycle-Unisex-Tub...     Get
# 1027  https://www.amazon.in/Layfuz-Chainring-104mm-4...     Get
#
#           no_of_ratings  discount_price  actual_price  \
# 246   Only1leftinstock.           599.0        675.00
# 424   Only1leftinstock.          1099.0       1599.00
# 1017  Only1leftinstock.          3300.0       4999.00
# 1027  Only1leftinstock.          1039.9       2179.57
#
#                                             name_preped  discount_amount
# 246   indialot bicycle tyre 20x 2125 195 190 175 mul...            76.00
# 424   dikudi creation doraemon rider infant toddler ...           500.00
# 1017  dhara kid bicycle 35 year size 14t unisex cycl...          1699.00
# 1027  layfuz 32t 34t 36t 38t bike chainring 104mm b ...          1139.67

# %% [markdown]
# #### All these listings have 'Get' in the ratings category, seems like a data entry error

# %%
cleaned[cleaned.ratings == 'Get']
# Out:
#                                                    name     main_category  \
# 214      BODYCARE Unisex Kids Thermal Bottoms Pack Of 1  sports & fitness
# 245                  Puma Footie Unisex Socks Pack of 3  sports & fitness
# 246   IndiaLot® Bicycle Tyre 20x 2.125/1.95/1.90/1.7...  sports & fitness
# 261   Charged Active-001 Camo Jacquard Round Neck Sp...  sports & fitness
#
# 1126  https://www.amazon.in/DHP-DOLPHIN-Nylon-Stocki...     Get
# 1144  https://www.amazon.in/ONN-Sleeves-Premium-Ther...     Get
#
#              no_of_ratings  discount_price  actual_price  \
# 214   FREEDeliverybyAmazon           625.0        625.00
# 245   FREEDeliverybyAmazon           599.0        599.00
# 246      Only1leftinstock.           599.0        675.00
# 261   FREEDeliverybyAmazon          1196.0       1348.00
# 272   FREEDeliverybyAmazon          1059.0       1059.00
# 412   FREEDeliverybyAmazon           919.0       1499.00
# 424      Only1leftinstock.          1099.0       1599.00
# 466   FREEDeliverybyAmazon          1198.0       1198.00
# 482   FREEDeliverybyAmazon          1248.0       1248.00
# 483   FREEDeliverybyAmazon          1198.0       1198.00
# 489   FREEDeliverybyAmazon          1196.0       1348.00
# 510   FREEDeliverybyAmazon           690.0        690.00
# 679   FREEDeliverybyAmazon           716.0       1098.00
# 680   FREEDeliverybyAmazon           849.0       1699.00
# 681   FREEDeliverybyAmazon           647.0        647.00
# 691      Only2leftinstock.           372.0        999.00
# 725   FREEDeliverybyAmazon           629.0        629.00
# 741   FREEDeliverybyAmazon          1750.0       1750.00
# 869   FREEDeliverybyAmazon           987.0       1048.00
# 870   FREEDeliverybyAmazon          1017.0       1148.00
# 871   FREEDeliverybyAmazon          1098.0       1098.00
# 875   FREEDeliverybyAmazon           628.0        628.00
# 933   FREEDeliverybyAmazon          3999.0      11000.00
# 1009  FREEDeliverybyAmazon          1714.0       1950.00
# 1015     Only2leftinstock.          4800.0       9000.00
# 1017     Only1leftinstock.          3300.0       4999.00
# 1027     Only1leftinstock.          1039.9       2179.57
# 1089  FREEDeliverybyAmazon           683.0        998.00
# 1090  FREEDeliverybyAmazon          1148.0       1148.00
# 1091  FREEDeliverybyAmazon          1011.0       1148.00
# 1116  FREEDeliverybyAmazon           609.0        609.00
# 1126     Only2leftinstock.           199.0        399.00
# 1144  FREEDeliverybyAmazon           620.0        620.00
#
#                                             name_preped  discount_amount
# 214           bodycare unisex kid thermal bottom pack 1             0.00
# 245                      puma footie unisex sock pack 3             0.00
# 246   indialot bicycle tyre 20x 2125 195 190 175 mul...            76.00
# 261   charged active001 camo jacquard round neck spo...           152.00
# 272    van heusencommavh woman woman relaxed fit tshirt             0.00
# 412           adidas unisex mufc h sock h13893l white l           580.00
# 424   dikudi creation doraemon rider infant toddler ...           500.00
# 466   charged active001 camo jacquard round neck spo...             0.00
# 482   charged active001 camo jacquard round neck spo...             0.00
# 483   charged active001 camo jacquard polyester roun...             0.00
# 489   charged active001 camo jacquard round neck spo...           152.00
# 510                      onn men premium thermal bottom             0.00
# 679   charged brisk002 melange round neck sport tshi...           382.00
# 680                      asics woman regular fit tshirt           850.00
# 681   dixcy scott grey melange men premium lower tro...             0.00
# 691   cycle tyre 16 x 240 bicycle tire 16 inch kid bike           627.00
# 725   nivia 23641 nitro1 polyester training tee adul...             0.00
# 741   lacoste men sport branded stretch cotton lowcu...             0.00
# 869   charged energy004 interlock knit hexagon embos...            61.00
# 870   charged brisk002 melange round neck sport tshi...           131.00
# 871   charged brisk002 melange round neck sport tshi...             0.00
# 875   dixcy scott charcoal melange men premium lower...             0.00
# 933   renewed sjcam action camera c100 2k 30fps 30m ...          7001.00
# 1009  yonex girl junior sport legging madel 1771 bad...           236.00
# 1015  cyclostar hero whistle 14t single speed kid bi...          4200.00
# 1017  dhara kid bicycle 35 year size 14t unisex cycl...          1699.00
# 1027  layfuz 32t 34t 36t 38t bike chainring 104mm b ...          1139.67
# 1089  charged play005 interlock knit geomatric embos...           315.00
# 1090  charged endure003 chameleon spandex knit round...             0.00
# 1091  charged endure003 chameleon spandex knit round...           137.00
# 1116  dixcy scott charcoal melange v neck full sleev...             0.00
# 1126  dhp dolphin nylon stocking football sock men w...           200.00
# 1144  onn men round neck half sleeve premium thermal...             0.00

# %% [markdown]
# ### The recommender system will be probably be using (ratings * no_of_ratings) to find which are the most popular products. If we fill these nonsense ratings with 0 then the products will be at the bottom of our recommendation list, which should be fine. So lets change the nonsence to 0s.

# %%
cleaned.ratings.unique()
# Out:
# array(['4.0', '4.1', '3.8', '3.9', '3.7', '3.6', '4.4', '4.3', '5.0',
#        '4.2', '3.5', '2.7', '3.4', '3.3', '4.6', '3.2', '4.8', '3.0',
#        '4.5', nan, '2.6', '1.0', '3.1', '2.8', '2.2', '2.9', 'Get', '4.7',
#        '1.9', '2.0', '2.4', '2.5', '1.7', '2.1', '1.8', '2.3'],
#       dtype=object)

# %%
cleaned.ratings = cleaned.ratings.str.replace('Get', '0', regex=False).\
    fillna('0').astype(float)

# %%
cleaned.no_of_ratings = cleaned.no_of_ratings.\
    str.replace('FREEDeliverybyAmazon', '0', regex=False).\
    str.replace('Only1leftinstock.', '0', regex=False).\
    str.replace('Only2leftinstock.', '0', regex=False).\
    fillna('0').astype(int)

# %%
cleaned.no_of_ratings.unique()
# Out:
# array([ 7635,  8052,  2214,  2974,  3678,  1444,  8334,    66,   566,
#         6580,  5117,  1601,  2759,  3457,    46,   632, 12842,  6596,
#         2507,   708,  1022,  1062,   768,   487,   268,    81,   447,
#          169,   424,   416,   485,     1,    23,  1145,   300,  2589,
#          252,  1270,    78,   144,    13,    65,   287,  4207,   203,
#           15,   121,   247,   870, 10244,   128,  1623,   316,  6083,
#          536,    26,    25,  2839,   180,    48,    29, 18123,   135,
#         1639,  1873,   157,    98,   240,   291,  1848,  2757,  1373,
#           16,     3,   241,   202,    75,   453,  2472,    24,    36,
#          951,     2,     4,   156,   125,     8,    51,     6,   383,
#           74,     0,    20,    50,     5,   119,   278,    18,    10,
#           14,   184,   133,   430,   159,    33,     9,    31,    12,
#           30,    64,  1111,    68,   104,    17,   267,   131,    54,
#           53,    39,    11,   255,    55,   130,    34,    59,    41,
#           40,   346,   149,   187,   122,    49,     7,   179,    22,
#          391,    58,    62,    60,   393,    82,    88,   113,    21,
#          232,   838,    56,    32,    89,   523,   272,    27,    19,
#          109,   139,   154,   111,   844,    69,    52, 19181,   243,
#          635,    43,   177, 13444,    73,   462,   168,    42,   298,
#           38,    85,    35,   186,    72,    95,   175,  4629,   335,
#         2069,   505,    28,   733,   196,    87,   421,   182,    37,
#          297,  1742,  6745,   138,  4200,  1906,    57,    79,    91,
#           63,   146,    77,   148,    71,    76,   155,   192,    47,
#           90,  1815,   103,   229, 16596,    67,   161,  2956])

# %%
cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1117 entries, 0 to 1151
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1117 non-null   object
#  1   main_category    1117 non-null   object
#  2   sub_category     1117 non-null   object
#  3   image            1117 non-null   object
#  4   link             1117 non-null   object
#  5   ratings          1117 non-null   float64
#  6   no_of_ratings    1117 non-null   int64
#  7   discount_price   1117 non-null   float64
#  8   actual_price     1117 non-null   float64
#  9   name_preped      1117 non-null   object
#  10  discount_amount  1117 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 104.7+ KB

# %% [markdown]
# ### The prices in this dataset are listed in ₹, Indian Rupees
# 1 rupee is approximately 0.012 US dollars
#
# Lets convert to US dollars since we are in USA and our other dataset uses dollars

# %%
cleaned.actual_price = round(cleaned.actual_price * 0.012, 2)
cleaned.discount_price = round(cleaned.discount_price * 0.012, 2)

# %%
cleaned.head()
# Out:
#                                                 name     main_category  \
# 0  QUXIS Portable High Pressure Foot Air Pump Hea...  sports & fitness
# 1  Boldfit Gym Shaker for Protein Shake Leakproof...  sports & fitness
# 2  Techista 2-in-1 Rechargeable - Cycle Light (3 ...  sports & fitness
# 3  Nivia Plain Encounter Stockings (L, Black) - P...  sports & fitness
# 4  Eazo Steel Multipurpose Air Pump with needle (...  sports & fitness
#
#   sub_category                                              image  \
# 0      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/QUXIS-Portable-Activated...      4.0           7635
# 1  https://www.amazon.in/Boldfit-Typhoon-Shaker-L...      4.1           8052
# 2  https://www.amazon.in/Techista-2-1-Rechargeabl...      4.1           2214
# 3  https://www.amazon.in/Nivia-728LBW-Encounter-B...      4.1           2974
# 4  https://www.amazon.in/EAZO-Steel-Multipurpose-...      4.1           3678
#
#    discount_price  actual_price  \
# 0            5.99         15.59
# 1            2.75          2.75
# 2            4.07         11.99
# 3            1.74          1.79
# 4            4.43          5.40
#
#                                          name_preped  discount_amount
# 0  quxis portable high pressure foot air pump hea...            800.0
# 1  boldfit gym shaker protein shake leakproof sha...              0.0
# 2  techista 2in1 rechargeable cycle light 3 mode ...            660.0
# 3  nivia plain encounter stocking l black polyest...              4.0
# 4  eazo steel multipurpose air pump needle use ca...             81.0

# %% [markdown]
# ## lets create a new column that is a product of the ratings and no_of_ratings to get an overalll rating_prod that we can use as a ranking of the products

# %%
cleaned['rating_prod'] = cleaned.ratings * cleaned.no_of_ratings

# %%
cleaned.head()
# Out:
#                                                 name     main_category  \
# 0  QUXIS Portable High Pressure Foot Air Pump Hea...  sports & fitness
# 1  Boldfit Gym Shaker for Protein Shake Leakproof...  sports & fitness
# 2  Techista 2-in-1 Rechargeable - Cycle Light (3 ...  sports & fitness
# 3  Nivia Plain Encounter Stockings (L, Black) - P...  sports & fitness
# 4  Eazo Steel Multipurpose Air Pump with needle (...  sports & fitness
#
#   sub_category                                              image  \
# 0      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4      Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/QUXIS-Portable-Activated...      4.0           7635
# 1  https://www.amazon.in/Boldfit-Typhoon-Shaker-L...      4.1           8052
# 2  https://www.amazon.in/Techista-2-1-Rechargeabl...      4.1           2214
# 3  https://www.amazon.in/Nivia-728LBW-Encounter-B...      4.1           2974
# 4  https://www.amazon.in/EAZO-Steel-Multipurpose-...      4.1           3678
#
#    discount_price  actual_price  \
# 0            5.99         15.59
# 1            2.75          2.75
# 2            4.07         11.99
# 3            1.74          1.79
# 4            4.43          5.40
#
#                                          name_preped  discount_amount  \
# 0  quxis portable high pressure foot air pump hea...            800.0
# 1  boldfit gym shaker protein shake leakproof sha...              0.0
# 2  techista 2in1 rechargeable cycle light 3 mode ...            660.0
# 3  nivia plain encounter stocking l black polyest...              4.0
# 4  eazo steel multipurpose air pump needle use ca...             81.0
#
#    rating_prod
# 0      30540.0
# 1      33013.2
# 2       9077.4
# 3      12193.4
# 4      15079.8

# %%
# time to test the wrangle_products.py file

# %%
import wrangle_products

# %%
df2 = wrangle_products.wrangle_products()
df2.head()
# Out:
# Opening local amazon_cycling.csv file
#                                                 name   amazon_main_cat  \
# 0  QUXIS Portable High Pressure Foot Air Pump Hea...  sports & fitness
# 1  Boldfit Gym Shaker for Protein Shake Leakproof...  sports & fitness
# 2  Techista 2-in-1 Rechargeable - Cycle Light (3 ...  sports & fitness
# 3  Nivia Plain Encounter Stockings (L, Black) - P...  sports & fitness
# 4  Eazo Steel Multipurpose Air Pump with needle (...  sports & fitness
#
#   amazon_sub_cat                                              image  \
# 0        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4        Cycling  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/QUXIS-Portable-Activated...      4.0           7635
# 1  https://www.amazon.in/Boldfit-Typhoon-Shaker-L...      4.1           8052
# 2  https://www.amazon.in/Techista-2-1-Rechargeabl...      4.1           2214
# 3  https://www.amazon.in/Nivia-728LBW-Encounter-B...      4.1           2974
# 4  https://www.amazon.in/EAZO-Steel-Multipurpose-...      4.1           3678
#
#    discount_price  actual_price  \
# 0            5.99         15.59
# 1            2.75          2.75
# 2            4.07         11.99
# 3            1.74          1.79
# 4            4.43          5.40
#
#                                          name_preped  discount_amount  \
# 0  quxis portable high pressure foot air pump hea...             9.60
# 1  boldfit gym shaker protein shake leakproof sha...             0.00
# 2  techista 2in1 rechargeable cycle light 3 mode ...             7.92
# 3  nivia plain encounter stocking l black polyest...             0.05
# 4  eazo steel multipurpose air pump needle use ca...             0.97
#
#    prod_rating
# 0      30540.0
# 1      33013.2
# 2       9077.4
# 3      12193.4
# 4      15079.8

# %%
sub_cat_list = ['Tires and Tubes', 'Gloves', 'Helmets', 'Bike Stands',
       'Mountain Bikes', 'Hydration Packs', 'Jerseys', 'Fenders',
       'Cleaners', 'Socks', 'Caps', 'Touring Bikes', 'Bottles and Cages',
       'Vests', 'Road Bikes', 'Bike Racks', 'Shorts']

# %%
cat_list = get_cat_list(sub_cat_list, extra_words=['bike', 'bikes'])

# %%
cat_list
# Out:
# ['tire tube',
#  'glove',
#  'helmet',
#  'stand',
#  'mountain',
#  'hydration pack',
#  'jersey',
#  'fender',
#  'cleaner',
#  'sock',
#  'cap',
#  'touring',
#  'bottle cage',
#  'vest',
#  'road',
#  'rack',
#  'short']

# %%
tires_and_tubes_regex = r'.*tire.*'

# %%
re.search(tires_and_tubes_regex, cleaned.name_preped[6])

# %%
horn_regex = r'.*horn.*'

# %%
re.search(horn_regex, cleaned.name_preped[6])
# match
# Out:
# <re.Match object; span=(0, 85), match='lista rechargeable bike horn light 140 db super b>

# %%
re.search(horn_regex, cleaned.name_preped[7])
# no match
