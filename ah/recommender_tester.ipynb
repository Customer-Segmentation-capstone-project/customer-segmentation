# %%
import pandas as pd
import product_recommend as p

# %%
p.get_cluster_product_rec(0)
# Out:
# Opening local amazon_cycling.csv file
#                                                   name   amazon_main_cat  \
# 0                   Fitkit Classic Bottle Shaker 700ml  sports & fitness
# 2    Boldfit Gym Shaker for Protein Shake Leakproof...  sports & fitness
# 5    SignoraWare Charger Stainless Steel Protein Sh...  sports & fitness
# 6    Geekey Multi-Tool – Key Shaped Pocket Tool for...  sports & fitness
# 13   DOVEAZ® Sports Water Bottle for Gym, Protein S...  sports & fitness
# ..                                                 ...               ...
# 815  IndiaLot® Bicycle Inner Tube 24x 2.125/1.95/1....  sports & fitness
# 825  LIGHTER HOUSE™ Bike Handlebar Bag Waterproof B...  sports & fitness
# 827  Vandana Enterprises CSTVI Sports Gym Shaker/Wa...  sports & fitness
# 834  Bike 24 Automobile,Alluminium Alloy Ring Bell ...  sports & fitness
# 844          Captain Lead to Win practice soccer socks  sports & fitness
#
# ...

# %%
p.get_cluster_product_rec(1)
# Out:
# Opening local amazon_cycling.csv file
#                                                   name   amazon_main_cat  \
# 6    Speedex Stainless Steel Vacuum Insulated Flask...  sports & fitness
# 14   KAMACHI Cycling Skating Helmet with Thick Exte...  sports & fitness
# 15   Lifelong Adjustable Cycling Helmet with Detach...  sports & fitness
# 26   ZAKPRO MTB Inmold Cycling Helmet with Rear LED...  sports & fitness
# 42   Firefox Bicycle Helmet V-32- Size-M (Green) (5...  sports & fitness
# 47   OCEAN RACE Women's Regular Fit Cotton Capris (...  sports & fitness
# 70   MPL Sports Official Team India Fan Test Jersey...  sports & fitness
# 72   FASTPED Bottle Shaped Bicycle Bike Bag Portabl...  sports & fitness
# 80   Strauss Silicone Gel Seat Cover with 3D Anti-S...  sports & fitness
# 92   Eryue Men's Summer Short Suits Cycling Set Cyc...  sports & fitness
# 97   Football Jersey for menPRO Static PSG Messi Ho...  sports & fitness
# ...

# %%
p.get_cluster_product_rec(2)
# Out:
# Opening local amazon_cycling.csv file
#                                                  name   amazon_main_cat  \
# 2   Leader Scout MTB 26T Mountain Bicycle/Bike Wit...  sports & fitness
# 9   Lifelong Without Gear Single Speed 26T MTB Cyc...  sports & fitness
# 11  Leader Kids Children, Boys, Girls 20T Road Bik...  sports & fitness
# 29  HERO CYCLES Fairy 20T Kids Steel Cycle (Tire 2...  sports & fitness
# 32              Lista Fluorescent Cycling Jersey Sets  sports & fitness
# 37  ROCKBROS 3D Shell Saddle Bag Cycling Seat Pack...  sports & fitness
# 42  SPEED BIRD 20-T New Flora Double Seat Carrier ...  sports & fitness
# 43  SPEED BIRD 16T New Flora Double Seat Carrier T...  sports & fitness
# 48  CYCLOSTAR STRYDER KORUS 26T Road Bicycle with ...  sports & fitness
# 54  Docooler 2Pcs Cycling Mountain Bike Bicycle MT...  sports & fitness
# 63  Dhara Kid Bicycle 3-5 Years Size 14T Unisex Cy...  sports & fitness
# ...

# %%
p.get_cluster_product_rec(3)
# Out:
# Opening local amazon_cycling.csv file
#                                                  name   amazon_main_cat  \
# 5   ROTTO Cycling Jersey Mens Bike Shirt Short Sle...  sports & fitness
# 8   Hero Hawk Nuage 27T Single Speed Hybrid / Road...  sports & fitness
# 13  BSA cycles Unisex-Adult Steel Photon Ex 18 Fra...  sports & fitness
# 14  Hercules Flunk HT 26T Single Speed Road Cycle ...  sports & fitness
# 15  Amazon Brand - Symactive Sprinter S2000 Series...  sports & fitness
# 16  Hercules Roadeo Turner 2016 26T Men's 21 Speed...  sports & fitness
# 18  FIFTY-FIFTY Mountain Bike Riser Handlebar, Alu...  sports & fitness
# 19  Cockatoo Men's CBC-05 Elite Series 26T & 21 Sp...  sports & fitness
# 20  Amardeep cycles Unisex Road Bike 700C with 14 ...  sports & fitness
# 22  Geekay Hashtag 27.5t Single Speed Steel Frame ...  sports & fitness
# 26  Hercules TOP Gear A29 R1 Mountain Bike with Sh...  sports & fitness
# ...
